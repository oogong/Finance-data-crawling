# %%
import OpenDartReader

# %%
api_key = 'abf4e3703b22eb082cd3977afbbcc0a6746afd61'

# %%
dart = OpenDartReader(api_key)

# %%
dart.major_shareholders('삼성전자')
# Out:
#           rcept_no    rcept_dt corp_code corp_name report_tp  repror  \
# 0   20220708000631  2022-07-08  00126380      삼성전자        일반    삼성물산
# 1   20220722000492  2022-07-22  00126380      삼성전자        일반    삼성물산
# 2   20220826000674  2022-08-26  00126380      삼성전자        일반    삼성물산
# 3   20220902000220  2022-09-02  00126380      삼성전자        약식  국민연금공단
# 4   20220916000466  2022-09-16  00126380      삼성전자        일반    삼성물산
# 5   20221021000405  2022-10-21  00126380      삼성전자        일반    삼성물산
# 6   20230120000563  2023-01-20  00126380      삼성전자        일반    삼성물산
# 7   20230203000495  2023-02-03  00126380      삼성전자        일반    삼성물산
# 8   20230217001683  2023-02-17  00126380      삼성전자        일반    삼성물산
# 9   20230421000685  2023-04-21  00126380      삼성전자        일반    삼성물산
# 10  20230428001621  2023-04-28  00126380      삼성전자        일반    삼성물산
# 11  20230504000774  2023-05-04  00126380      삼성전자        일반    삼성물산
# 12  20230512001323  2023-05-12  00126380      삼성전자        일반    삼성물산
# 13  20230519000524  2023-05-19  00126380      삼성전자        일반    삼성물산
# 14  20230721000556  2023-07-21  00126380      삼성전자        일반    삼성물산
# 15  20230728000726  2023-07-28  00126380      삼성전자        일반    삼성물산
# 16  20230818000461  2023-08-18  00126380      삼성전자        일반    삼성물산
# 17  20230908000465  2023-09-08  00126380      삼성전자        일반    삼성물산
# 18  20231020000553  2023-10-20  00126380      삼성전자        일반    삼성물산
# 19  20231027000502  2023-10-27  00126380      삼성전자        일반    삼성물산
# 20  20231103000394  2023-11-03  00126380      삼성전자        일반    삼성물산
# 21  20231117000321  2023-11-17  00126380      삼성전자        일반    삼성물산
# 22  20240115000346  2024-01-15  00126380      삼성전자        일반    삼성물산
# 23  20240119000573  2024-01-19  00126380      삼성전자        일반    삼성물산
# 24  20240126000600  2024-01-26  00126380      삼성전자        일반    삼성물산
# 25  20240216001437  2024-02-16  00126380      삼성전자        일반    삼성물산
# 26  20240322001050  2024-03-22  00126380      삼성전자        일반    삼성물산
# 27  20240412003808  2024-04-12  00126380      삼성전자        일반    삼성물산
# 28  20240419000717  2024-04-19  00126380      삼성전자        일반    삼성물산
# 29  20240426000975  2024-04-26  00126380      삼성전자        일반    삼성물산
# 30  20240503000782  2024-05-03  00126380      삼성전자        일반    삼성물산
# 31  20240517000385  2024-05-17  00126380      삼성전자        일반    삼성물산
# 32  20240524000517  2024-05-24  00126380      삼성전자        일반    삼성물산
#
#             stkqy   stkqy_irds  stkrt stkrt_irds    ctr_stkqy ctr_stkrt  \
# 0   1,241,131,025      -43,788  20.79      -0.00   98,682,587      1.65
# 1   1,241,273,657      142,632  20.79       0.00   98,282,587      1.65
# 2   1,241,213,913      -59,744  20.79      -0.00  101,535,587      1.70
# 3     458,637,667  -59,871,911   7.68      -1.01            -         -
# 4   1,241,176,035      -37,878  20.79      -0.00  102,026,587      1.71
# 5   1,238,767,819   -2,408,216  20.75      -0.04  103,716,587      1.74
# 6   1,237,964,708     -803,111  20.74      -0.01  103,716,587      1.74
# 7   1,237,908,256      -56,452  20.74      -0.00  108,897,005      1.82
# 8   1,237,907,158       -1,098  20.74      -0.00  108,897,005      1.82
# 9   1,237,590,814     -316,344  20.73      -0.01  121,175,005      2.03
# 10  1,237,595,226        4,412  20.73       0.00  121,175,005      2.03
# 11  1,237,666,781       71,555  20.73       0.00  165,335,044      2.77
# 12  1,237,663,877       -2,904  20.73      -0.00  159,479,145      2.67
# 13  1,237,664,907        1,030  20.73       0.00  159,479,145      2.67
# 14  1,237,123,070     -541,837  20.72      -0.01  159,479,145      2.67
# 15  1,236,915,000     -208,070  20.72      -0.00  159,479,145      2.67
# 16  1,236,841,729      -73,271  20.72      -0.00  159,479,145      2.67
# 17  1,236,691,824     -149,905  20.72      -0.00  159,221,145      2.67
# 18  1,236,346,038     -345,786  20.71      -0.01  159,221,145      2.67
# 19  1,236,232,754     -113,284  20.71      -0.00  159,221,145      2.67
# 20  1,236,195,301      -37,453  20.71      -0.00  189,050,328      3.17
# 21  1,236,157,473      -37,828  20.71      -0.00  189,050,328      3.17
# 22  1,205,765,181  -30,392,292  20.20      -0.51  159,221,145      2.67
# 23  1,205,805,585       40,404  20.20       0.00  154,219,880      2.58
# 24  1,205,808,662        3,077  20.20       0.00  141,061,717      2.36
# 25  1,205,523,727     -284,935  20.19      -0.01  141,061,717      2.36
# 26  1,205,229,946     -293,781  20.19       0.00  146,308,857      2.45
# 27  1,199,897,278   -5,332,668  20.10      -0.09  141,061,717      2.36
# 28  1,199,849,964      -47,314  20.10      -0.00  128,951,727      2.16
# 29  1,199,540,016     -309,948  20.09      -0.01  124,250,104      2.08
# 30  1,199,477,193      -62,823  20.09      -0.00  133,395,104      2.23
# 31  1,199,491,688       14,495  20.09       0.00  133,395,104      2.23
# 32  1,199,285,813     -205,875  20.09      -0.00   97,526,980      1.63
#
#                                  report_resn
# 0   - 특별관계자 및 보유주식수 변동\n- 보유주식등에 관한 계약 관련 변경
# 1             - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 2             - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 3                                  단순추가취득/처분
# 4           - 보유주식수 변동\n- 보유주식등에 관한 계약 관련 변경
# 5             - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 6             - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 7             - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 8             - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 9          - 보유주식수 변동\n- 보유주식등에 관한 계약의 체결ㆍ변경
# 10            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 11         - 보유주식수 변동\n- 보유주식등에 관한 계약의 체결ㆍ변경
# 12            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 13            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 14            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 15            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 16            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 17            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 18            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 19            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 20          - 보유주식수 변동\n- 유가증권신탁(보유형태 변경 포함)
# 21            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 22                    - 보유주식수 변동\n- 신탁 주식 처분
# 23            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 24            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 25            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 26  - 특별관계자 및 보유주식수 변동\n- 유가증권신탁(보유형태 변경 포함)
# 27                     - 보유주식수 변동\n- 신탁주식 처분
# 28            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 29            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 30            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 31            - 보유주식수 변동\n- 보유주식등에 관한 계약의 변경
# 32    - 특별관계자 및 보유주식수 변동\n- 보유주식등에 관한 계약의 변경

# %%
dart.list('삼성전자')
# Out:
#      corp_code corp_name stock_code corp_cls              report_nm  \
# 0     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# 1     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# 2     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# 3     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# 4     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# ...        ...       ...        ...      ...                    ...
# 5913  00126380      삼성전자     005930        Y           채무보증(담보제공포함)
# 5914  00126380      삼성전자     005930        Y          최대주주등을위한금전의대여
# 5915  00126380      삼성전자     005930        Y        감사보고서 (1999.12)
# 5916  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 5917  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
#
#             rcept_no  flr_nm  rcept_dt rm
# 0     20240607000054     윤주한  20240607
# 1     20240607000045     박순철  20240607
# 2     20240607000008     김동욱  20240607
# 3     20240604000031     노태문  20240604
# 4     20240604000023     박학규  20240604
# ...              ...     ...       ... ..
# 5913  20000404000429    삼성전자  20000404
# 5914  20000401000031    삼성전자  20000401
# 5915  20000320000124  삼일회계법인  20000320
# 5916  19990824000003    삼성전자  19990824
# 5917  19990626000007    삼성전자  19990626  연
#
# [5918 rows x 9 columns]

# %%
fs = dart.finstate('005930', '2023', reprt_code='11011')
fs
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 1   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 2   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 3   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 4   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 5   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 6   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 7   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 8   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 9   20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 10  20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 11  20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 12  20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 13  20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 14  20240312000736      11011      2023  00126380     005930    CFS  연결재무제표
# 15  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 16  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 17  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 18  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 19  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 20  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 21  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 22  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 23  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 24  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 25  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 26  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 27  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 28  20240312000736      11011      2023  00126380     005930    OFS    재무제표
# 29  20240312000736      11011      2023  00126380     005930    OFS    재무제표
#
#    sj_div  sj_nm  account_nm  ...                thstrm_dt  \
# 0      BS  재무상태표        유동자산  ...            2023.12.31 현재
# 1      BS  재무상태표       비유동자산  ...            2023.12.31 현재
# 2      BS  재무상태표        자산총계  ...            2023.12.31 현재
# 3      BS  재무상태표        유동부채  ...            2023.12.31 현재
# 4      BS  재무상태표       비유동부채  ...            2023.12.31 현재
# 5      BS  재무상태표        부채총계  ...            2023.12.31 현재
# 6      BS  재무상태표         자본금  ...            2023.12.31 현재
# 7      BS  재무상태표       이익잉여금  ...            2023.12.31 현재
# 8      BS  재무상태표        자본총계  ...            2023.12.31 현재
# 9      IS  손익계산서         매출액  ...  2023.01.01 ~ 2023.12.31
# 10     IS  손익계산서        영업이익  ...  2023.01.01 ~ 2023.12.31
# 11     IS  손익계산서  법인세차감전 순이익  ...  2023.01.01 ~ 2023.12.31
# 12     IS  손익계산서       당기순이익  ...  2023.01.01 ~ 2023.12.31
# 13     IS  손익계산서   당기순이익(손실)  ...  2023.01.01 ~ 2023.12.31
# 14     IS  손익계산서       총포괄손익  ...  2023.01.01 ~ 2023.12.31
# 15     BS  재무상태표        유동자산  ...            2023.12.31 현재
# 16     BS  재무상태표       비유동자산  ...            2023.12.31 현재
# 17     BS  재무상태표        자산총계  ...            2023.12.31 현재
# 18     BS  재무상태표        유동부채  ...            2023.12.31 현재
# 19     BS  재무상태표       비유동부채  ...            2023.12.31 현재
# 20     BS  재무상태표        부채총계  ...            2023.12.31 현재
# 21     BS  재무상태표         자본금  ...            2023.12.31 현재
# 22     BS  재무상태표       이익잉여금  ...            2023.12.31 현재
# 23     BS  재무상태표        자본총계  ...            2023.12.31 현재
# 24     IS  손익계산서         매출액  ...  2023.01.01 ~ 2023.12.31
# 25     IS  손익계산서        영업이익  ...  2023.01.01 ~ 2023.12.31
# 26     IS  손익계산서  법인세차감전 순이익  ...  2023.01.01 ~ 2023.12.31
# 27     IS  손익계산서       당기순이익  ...  2023.01.01 ~ 2023.12.31
# 28     IS  손익계산서   당기순이익(손실)  ...  2023.01.01 ~ 2023.12.31
# 29     IS  손익계산서       총포괄손익  ...  2023.01.01 ~ 2023.12.31
#
#           thstrm_amount frmtrm_nm                frmtrm_dt  \
# 0   195,936,557,000,000    제 54 기            2022.12.31 현재
# 1   259,969,423,000,000    제 54 기            2022.12.31 현재
# 2   455,905,980,000,000    제 54 기            2022.12.31 현재
# 3    75,719,452,000,000    제 54 기            2022.12.31 현재
# 4    16,508,663,000,000    제 54 기            2022.12.31 현재
# 5    92,228,115,000,000    제 54 기            2022.12.31 현재
# 6       897,514,000,000    제 54 기            2022.12.31 현재
# 7   346,652,238,000,000    제 54 기            2022.12.31 현재
# 8   363,677,865,000,000    제 54 기            2022.12.31 현재
# 9   258,935,494,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 10    6,566,976,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 11   11,006,265,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 12   15,487,100,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 13   15,487,100,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 14   18,837,411,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 15   68,548,442,000,000    제 54 기            2022.12.31 현재
# 16  228,308,847,000,000    제 54 기            2022.12.31 현재
# 17  296,857,289,000,000    제 54 기            2022.12.31 현재
# 18   41,775,101,000,000    제 54 기            2022.12.31 현재
# 19   30,294,414,000,000    제 54 기            2022.12.31 현재
# 20   72,069,515,000,000    제 54 기            2022.12.31 현재
# 21      897,514,000,000    제 54 기            2022.12.31 현재
# 22  219,963,351,000,000    제 54 기            2022.12.31 현재
# 23  224,787,774,000,000    제 54 기            2022.12.31 현재
# 24  170,374,090,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 25  -11,526,297,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 26   17,531,500,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 27   25,397,099,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 28   25,397,099,000,000    제 54 기  2022.01.01 ~ 2022.12.31
# 29   25,181,020,000,000    제 54 기  2022.01.01 ~ 2022.12.31
#
#           frmtrm_amount bfefrmtrm_nm             bfefrmtrm_dt  \
# 0   218,470,581,000,000       제 53 기            2021.12.31 현재
# 1   229,953,926,000,000       제 53 기            2021.12.31 현재
# 2   448,424,507,000,000       제 53 기            2021.12.31 현재
# 3    78,344,852,000,000       제 53 기            2021.12.31 현재
# 4    15,330,051,000,000       제 53 기            2021.12.31 현재
# 5    93,674,903,000,000       제 53 기            2021.12.31 현재
# 6       897,514,000,000       제 53 기            2021.12.31 현재
# 7   337,946,407,000,000       제 53 기            2021.12.31 현재
# 8   354,749,604,000,000       제 53 기            2021.12.31 현재
# 9   302,231,360,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 10   43,376,630,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 11   46,440,474,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 12   55,654,077,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 13   55,654,077,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 14   59,659,741,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 15   59,062,658,000,000       제 53 기            2021.12.31 현재
# 16  201,021,092,000,000       제 53 기            2021.12.31 현재
# 17  260,083,750,000,000       제 53 기            2021.12.31 현재
# 18   46,086,047,000,000       제 53 기            2021.12.31 현재
# 19    4,581,512,000,000       제 53 기            2021.12.31 현재
# 20   50,667,559,000,000       제 53 기            2021.12.31 현재
# 21      897,514,000,000       제 53 기            2021.12.31 현재
# 22  204,388,016,000,000       제 53 기            2021.12.31 현재
# 23  209,416,191,000,000       제 53 기            2021.12.31 현재
# 24  211,867,483,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 25   25,319,329,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 26   29,691,920,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 27   25,418,778,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 28   25,418,778,000,000       제 53 기  2021.01.01 ~ 2021.12.31
# 29   26,031,896,000,000       제 53 기  2021.01.01 ~ 2021.12.31
#
#        bfefrmtrm_amount ord currency
# 0   218,163,185,000,000   1      KRW
# 1   208,457,973,000,000   3      KRW
# 2   426,621,158,000,000   5      KRW
# 3    88,117,133,000,000   7      KRW
# 4    33,604,094,000,000   9      KRW
# 5   121,721,227,000,000  11      KRW
# 6       897,514,000,000  13      KRW
# 7   293,064,763,000,000  17      KRW
# 8   304,899,931,000,000  21      KRW
# 9   279,604,799,000,000  23      KRW
# 10   51,633,856,000,000  25      KRW
# 11   53,351,827,000,000  27      KRW
# 12   39,907,450,000,000  29      KRW
# 13   39,907,450,000,000  61      KRW
# 14   49,909,749,000,000  63      KRW
# 15   73,553,416,000,000   2      KRW
# 16  177,558,768,000,000   4      KRW
# 17  251,112,184,000,000   6      KRW
# 18   53,067,303,000,000   8      KRW
# 19    4,851,149,000,000  10      KRW
# 20   57,918,452,000,000  12      KRW
# 21      897,514,000,000  15      KRW
# 22  188,774,335,000,000  19      KRW
# 23  193,193,732,000,000  22      KRW
# 24  199,744,705,000,000  24      KRW
# 25   31,993,162,000,000  26      KRW
# 26   38,704,492,000,000  28      KRW
# 27   30,970,954,000,000  30      KRW
# 28   30,970,954,000,000  62      KRW
# 29   30,357,729,000,000  64      KRW
#
# [30 rows x 21 columns]

# %%
sales_row = fs[(fs['account_nm'] == '매출액') & (fs['fs_nm'] == '재무제표')]
print(sales_row)

# thstrm_amount와 frmtrm_amount 데이터를 문자열로 가져오기
thstrm_amount_str = sales_row['thstrm_amount'].values[0]
frmtrm_amount_str = sales_row['frmtrm_amount'].values[0]

# 쉼표를 제거하고 float로 변환
thstrm_amount = float(thstrm_amount_str.replace(',', ''))
print(thstrm_amount)
frmtrm_amount = float(frmtrm_amount_str.replace(',', ''))
print(frmtrm_amount)
# 매출액 증가율 계산
sales_growth_rate = ((thstrm_amount / frmtrm_amount) - 1) * 100

print(f"매출액 증가율: {sales_growth_rate:.2f}%")
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div fs_nm  \
# 24  20240312000736      11011      2023  00126380     005930    OFS  재무제표
#
#    sj_div  sj_nm account_nm  ...                thstrm_dt  \
# 24     IS  손익계산서        매출액  ...  2023.01.01 ~ 2023.12.31
#
#           thstrm_amount frmtrm_nm                frmtrm_dt  \
# 24  170,374,090,000,000    제 54 기  2022.01.01 ~ 2022.12.31
#
#           frmtrm_amount bfefrmtrm_nm             bfefrmtrm_dt  \
# 24  211,867,483,000,000       제 53 기  2021.01.01 ~ 2021.12.31
#
#        bfefrmtrm_amount ord currency
# 24  199,744,705,000,000  24      KRW
#
# [1 rows x 21 columns]
# 170374090000000.0
# 211867483000000.0
# 매출액 증가율: -19.58%

# %%
import pandas as pd
import OpenDartReader
import json

# DART API를 사용하기 위한 초기화 (API 키가 필요합니다)
api_key = 'abf4e3703b22eb082cd3977afbbcc0a6746afd61'
dart = OpenDartReader(api_key)

# JSON 파일 로드
with open('name.json', 'r', encoding='utf-8') as file:
    company_list = json.load(file)

# 함수: 매출액 증가율 계산
def calculate_sales_growth_rate(fs, year):
    sales_row = fs[(fs['account_nm'] == '매출액') & (fs['fs_nm'] == '재무제표')]
    if sales_row.empty:
        return None
    thstrm_amount_str = sales_row['thstrm_amount'].values[0]
    frmtrm_amount_str = sales_row['frmtrm_amount'].values[0]
    thstrm_amount = float(thstrm_amount_str.replace(',', ''))
    frmtrm_amount = float(frmtrm_amount_str.replace(',', ''))
    sales_growth_rate = ((thstrm_amount / frmtrm_amount) - 1) * 100
    return sales_growth_rate

# 결과를 저장할 리스트
results = []

# 각 회사에 대해 매출액 증가율 계산
for company in company_list:
    code = company['Code']
    result = {'종목코드': code}
    for year in [2023, 2022, 2021]:
        try:
            fs = dart.finstate(code, str(year), reprt_code='11011')
            sgr = calculate_sales_growth_rate(fs, year)
            result[f'{year}_SGR'] = sgr
        except Exception as e:
            result[f'{year}_SGR'] = None
            print(f"Error processing {code} for year {year}: {e}")
    results.append(result)

# DataFrame으로 변환
df = pd.DataFrame(results)

# 컬럼 순서 정렬
df = df[['종목코드', '2023_SGR', '2022_SGR', '2021_SGR']]

# CSV 파일로 저장
df.to_csv('sales_growth_rate.csv', index=False)

print("CSV 파일이 저장되었습니다: sales_growth_rate.csv")
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 105560 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 105560 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 055550 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 055550 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 086790 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 086790 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 000810 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 000810 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 032830 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 032830 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 138040 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 138040 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 024110 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 024110 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 323410 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 323410 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 316140 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 316140 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 402340 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 402340 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 005830 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 005830 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 450080 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 029780 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 029780 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 006800 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 006800 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 005940 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 005940 for year 2021: '<' not supported between instances of 'str' and 'int'
# Error processing 302440 for year 2022: HTTPSConnectionPool(host='opendart.fss.or.kr', port=443): Max retries exceeded with url: /api/fnlttSinglAcnt.json?crtfc_key=abf4e3703b22eb082cd3977afbbcc0a6746afd61&corp_code=01319899&bsns_year=2022&reprt_code=11011 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 071050 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 071050 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 039490 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 039490 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 016360 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 016360 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 001450 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 001450 for year 2021: '<' not supported between instances of 'str' and 'int'
# Error processing 383220 for year 2021: could not convert string to float: '-'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 138930 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 138930 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 175330 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 175330 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 088350 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 088350 for year 2021: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 139130 for year 2022: '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Error processing 139130 for year 2021: '<' not supported between instances of 'str' and 'int'
# Error processing 375500 for year 2021: could not convert string to float: '-'
# CSV 파일이 저장되었습니다: sales_growth_rate.csv

# %%
import pandas as pd
import OpenDartReader
import json

# DART API를 사용하기 위한 초기화 (API 키가 필요합니다)
api_key = 'abf4e3703b22eb082cd3977afbbcc0a6746afd61'
dart = OpenDartReader(api_key)

# JSON 파일 로드
with open('name.json', 'r', encoding='utf-8') as file:
    company_list = json.load(file)

# 함수: 매출액 증가율 계산
def calculate_sales_growth_rate(fs):
    sales_row = fs[(fs['account_nm'] == '매출액') & (fs['fs_nm'] == '재무제표')]
    if sales_row.empty:
        return None
    thstrm_amount_str = sales_row['thstrm_amount'].values[0]
    frmtrm_amount_str = sales_row['frmtrm_amount'].values[0]
    thstrm_amount = float(thstrm_amount_str.replace(',', ''))
    frmtrm_amount = float(frmtrm_amount_str.replace(',', ''))
    sales_growth_rate = ((thstrm_amount / frmtrm_amount) - 1) * 100
    return sales_growth_rate

# 결과를 저장할 리스트
results = []

# 각 회사에 대해 2023년 매출액 증가율 계산
for company in company_list:
    code = company['Code']
    result = {'종목코드': code}
    print(result)
    try:
        fs = dart.finstate(code, '2023', reprt_code='11011')
        sgr = calculate_sales_growth_rate(fs)
        result['2023_SGR'] = sgr
    except Exception as e:
        result['2023_SGR'] = None
        print(f"Error processing {code} for year 2023: {e}")
    results.append(result)

# DataFrame으로 변환
df = pd.DataFrame(results)

# 컬럼 순서 정렬
df = df[['종목코드', '2023_SGR']]

# CSV 파일로 저장
df.to_csv('sales_growth_rate_2023.csv', index=False)

print("CSV 파일이 저장되었습니다: sales_growth_rate_2023.csv")
